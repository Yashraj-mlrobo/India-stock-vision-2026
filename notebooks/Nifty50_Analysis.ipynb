# %% [markdown]
# # Nifty 50 Analysis & Forecasting
# Project: India Stock Vision 2026

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Loading the processed data
df = pd.read_csv('../data/processed/NSEI_processed.csv', index_col=0, parse_dates=True)
df[['Close', 'SMA_50', 'SMA_200']].plot(figsize=(12,6))
plt.title('Nifty 50 Trend Analysis')
plt.show()
